# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('CanabisBenefits.csv')

# %%
media = df['popular interest'].mean()

# %%
print(f'Média: {media}')
# Out:
# Média: 456237.53623188403

# %%
mediana = df['popular interest'].median()

# %%
print(f'Mediana: {mediana}')
# Out:
# Mediana: 412000.0

# %%
variancia = df['popular interest'].var()

# %%
print(f'Variancia: {variancia}')
# Out:
# Variancia: 337545922012.9584

# %%
desvio_padrao = df['popular interest'].std()

# %%
print(f'Desvio padrao: {desvio_padrao}')
# Out:
# Desvio padrao: 580987.0239626341

# %%
origem_dos_dados = "Os dados foram obtidos da [Kaggle] em [03 de setembro de 2023]."

# %%
canabis_benefits = "O conjunto de dados é chamado de 'Canabis Benefits'."

# %%
num_registros = len(df)
tamanho = df.shape
quantidade_registros = tamanho[0]
quantidade_colunas = tamanho[1]

# %%
dados_faltantes = df.isna().sum()

# %%
print("Descrição do Conjunto de Dados\n")
print("Origem dos Dados:")
print(origem_dos_dados)
# Out:
# Descrição do Conjunto de Dados
#
# Origem dos Dados:
# Os dados foram obtidos da [Kaggle] em [03 de setembro de 2023].

# %%
print("\nNome do Conjunto de Dados:")
print(canabis_benefits)
# Out:
# Nome do Conjunto de Dados:
# O conjunto de dados é chamado de 'Canabis Benefits'.

# %%
print("\nTamanho e Quantidade de Registros:")
print(f"O conjunto de dados contém um total de {quantidade_registros} registros e {quantidade_colunas} colunas.")
# Out:
# Tamanho e Quantidade de Registros:
# O conjunto de dados contém um total de 69 registros e 14 colunas.

# %%
print("\nLinhas x Colunas:")
print(f"O conjunto de dados possui {tamanho[0]} linhas e {tamanho[1]} colunas.")
# Out:
# Linhas x Colunas:
# O conjunto de dados possui 69 linhas e 14 colunas.

# %%
print("\nDados Faltantes:")
print("A seguir, são apresentados o número de dados faltantes em cada coluna do conjunto de dados:")
print(dados_faltantes)
# Out:
# Dados Faltantes:
# A seguir, são apresentados o número de dados faltantes em cada coluna do conjunto de dados:
# health condition                                                                        0
# alternate name                                                                         64
# health condition.1                                                                      0
# evidence score 0 = harmful \n1 = no / insufficient evidence\n6 = strong                 0
# popular interest                                                                        0
# Number of citations on Google Scholar (2000-2017) search format: condition+cannabis     0
# CBD                                                                                    49
# simple English notes                                                                    0
# notes                                                                                   0
# ...

# %%
pip install matplotlib seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      ------- ----------------------------- 61.4/293.3 kB 656.4 kB/s eta 0:00:01
#      ---------------------- --------------- 174.1/293.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
descritivo_estatistico = df.describe()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='popular interest', bins=20, kde=True) 
plt.title('Histograma da Popular Interest')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()
# Out:
# C:\Windows\System32\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Windows\System32\myenv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='health condition', y='popular interest') 
plt.title('Scatter Plot entre health condition e popular interest')
plt.xlabel('health condition')
plt.ylabel('popular interest')
plt.show()
# Out:
# C:\Windows\System32\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Windows\System32\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Windows\System32\myenv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
